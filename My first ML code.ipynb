# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"C:\Users\LENOVO\Desktop\hipedata.xlsx")

# %%
mydata
# Out:
#     Gender  Height  weight
# 0     male     150      70
# 1   female     154      72
# 2     male     158      74
# 3   female     162      76
# 4   female     166      60
# 5   female     170      62
# 6     male     174      64
# 7   female     162      66
# 8     male     164      68
# 9   female     166      70
# 10    male     168      72
# 11    male     170      92
# 12    male     172      94
# 13  female     174      96
# 14    male     176      98
# 15  female     178      80
# 16  female     180      82
# 17  female     182      84
# 18    male     184      86
# 19  female     172      84

# %%
mydata.keys()
# Out:
# Index(['Gender', 'Height', 'weight'], dtype='object')

# %%
Index_name=pd.Series(['Extremely weak', 'weak', 'Normal', 'Overweight', 'Obesity', 'Extrem obesity'])

# %%
Index_name
# Out:
# 0    Extremely weak
# 1              weak
# 2            Normal
# 3        Overweight
# 4           Obesity
# 5    Extrem obesity
# dtype: object

# %%
mydata.head()
# Out:
#    Gender  Height  weight
# 0    male     150      70
# 1  female     154      72
# 2    male     158      74
# 3  female     162      76
# 4  female     166      60

# %%
mydata.tail()
# Out:
#     Gender  Height  weight
# 15  female     178      80
# 16  female     180      82
# 17  female     182      84
# 18    male     184      86
# 19  female     172      84

# %%
male_data=mydata[mydata["Gender"]=="male"]

# %%
male_data
# Out:
#    Gender  Height  weight
# 0    male     150      70
# 2    male     158      74
# 6    male     174      64
# 8    male     164      68
# 10   male     168      72
# 11   male     170      92
# 12   male     172      94
# 14   male     176      98
# 18   male     184      86

# %%
female_data=mydata[mydata["Gender"]=="female"]

# %%
female_data
# Out:
#     Gender  Height  weight
# 1   female     154      72
# 3   female     162      76
# 4   female     166      60
# 5   female     170      62
# 7   female     162      66
# 9   female     166      70
# 13  female     174      96
# 15  female     178      80
# 16  female     180      82
# 17  female     182      84
# 19  female     172      84

# %%
mydata[["Gender", "Height"]]
# Out:
#     Gender  Height
# 0     male     150
# 1   female     154
# 2     male     158
# 3   female     162
# 4   female     166
# 5   female     170
# 6     male     174
# 7   female     162
# 8     male     164
# 9   female     166
# 10    male     168
# 11    male     170
# 12    male     172
# 13  female     174
# 14    male     176
# 15  female     178
# 16  female     180
# 17  female     182
# 18    male     184
# 19  female     172

# %%
mydropdata=mydata.drop("weight", axis=1)

# %%
mydropdata
# Out:
#     Gender  Height
# 0     male     150
# 1   female     154
# 2     male     158
# 3   female     162
# 4   female     166
# 5   female     170
# 6     male     174
# 7   female     162
# 8     male     164
# 9   female     166
# 10    male     168
# 11    male     170
# 12    male     172
# 13  female     174
# 14    male     176
# 15  female     178
# 16  female     180
# 17  female     182
# 18    male     184
# 19  female     172

# %%
mydata["weight"].max()
# Out:
# 98

# %%
mydata["weight"].min()
# Out:
# 60

# %%
mydata["weight"].sum()
# Out:
# 1550

# %%
mydata[mydata["weight"]==mydata.weight.min()]
# Out:
#    Gender  Height  weight
# 4  female     166      60

# %%
mydata[mydata["Height"]==mydata.Height.max()]
# Out:
#    Gender  Height  weight
# 18   male     184      86

# %%
mydata.shape
# Out:
# (20, 3)

# %%
male_data.shape
# Out:
# (9, 3)

# %%
female_data.shape
# Out:
# (11, 3)

# %%
mydata["Total"]=mydata["Height"]+mydata["weight"]

# %%
mydata
# Out:
#     Gender  Height  weight  Total
# 0     male     150      70    220
# 1   female     154      72    226
# 2     male     158      74    232
# 3   female     162      76    238
# 4   female     166      60    226
# 5   female     170      62    232
# 6     male     174      64    238
# 7   female     162      66    228
# 8     male     164      68    232
# 9   female     166      70    236
# 10    male     168      72    240
# 11    male     170      92    262
# 12    male     172      94    266
# 13  female     174      96    270
# 14    male     176      98    274
# 15  female     178      80    258
# 16  female     180      82    262
# 17  female     182      84    266
# 18    male     184      86    270
# 19  female     172      84    256
